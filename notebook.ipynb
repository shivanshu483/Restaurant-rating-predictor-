# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Restaurant-dataset.csv")
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %% [markdown]
# ### Group by city and calculate average cost

# %%
df.groupby('City')['Average Cost for two'].mean().sort_values(ascending=False).reset_index().head()
# Out:
#          City  Average Cost for two
# 0     Jakarta         308437.500000
# 1   Tangerang         250000.000000
# 2       Bogor         160000.000000
# 3     Bandung         150000.000000
# 4  Pasay City           3333.333333

# %%
df.groupby('City')['Average Cost for two'].mean().sort_values(ascending=False).head().plot(kind='bar')
plt.title("Averege Cost City Wise")
plt.ylabel("Amount")
plt.grid()
plt.show()

# %% [markdown]
# ### Cuisines total number of vots

# %%
data = df.groupby('Cuisines')['Votes'].sum().sort_values(ascending = True).reset_index()

# %%
data[data['Votes']!= 0]
# Out:
#                                              Cuisines  Votes
# 48               North Eastern, North Indian, Chinese      1
# 49    Mithai, Street Food, North Indian, South Indian      1
# 50                                       Cafe, French      1
# 51                             Desserts, North Indian      1
# 52                      Awadhi, Mughlai, North Indian      1
# ...                                               ...    ...
# 1820                                          Chinese  21925
# 1821                                             Cafe  30657
# 1822                            North Indian, Chinese  42012
# 1823                                     North Indian  46241
# 1824                            North Indian, Mughlai  53747
#
# [1777 rows x 2 columns]

# %%
data[data['Votes']== 0]
# Out:
#                                              Cuisines  Votes
# 0                    Italian, Fast Food, South Indian      0
# 1                     Lucknowi, Mughlai, North Indian      0
# 2                                  Fast Food, Mughlai      0
# 3                      Italian, Continental, American      0
# 4                                    Bengali, Chinese      0
# 5                               North Indian, Seafood      0
# 6   North Indian, South Indian, Chinese, Fast Food...      0
# 7   North Indian, South Indian, Chinese, Healthy F...      0
# 8                          Fast Food, Chinese, Burger      0
# 9        North Indian, South Indian, Italian, Chinese      0
# 10                    Fast Food, South Indian, Mithai      0
# 11                            Beverages, Healthy Food      0
# 12                                   Pizza, Ice Cream      0
# 13                                Cafe, North Eastern      0
# ...

# %%
sns.pairplot(df[['Aggregate rating','Average Cost for two','Votes']])
# Out:
# c:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(3, 3))  
df['Has Online delivery'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    startangle=90,
    wedgeprops={'edgecolor': 'black'}
)

plt.title("How has online delivery?")
plt.ylabel('')
# plt.legend()
plt.show()

# %%
df[['Aggregate rating','Rating text']].sort_values(by = 'Aggregate rating',ascending = True).head(5000)
# Out:
#       Aggregate rating Rating text
# 6615               0.0   Not rated
# 1994               0.0   Not rated
# 1995               0.0   Not rated
# 1996               0.0   Not rated
# 1997               0.0   Not rated
# ...                ...         ...
# 9238               3.2     Average
# 2051               3.2     Average
# 2832               3.2     Average
# 143                3.2     Average
# 4541               3.2     Average
#
# [5000 rows x 2 columns]

# %% [markdown]
# ## Filtering the data frame:

# %%
df = df[df['Rating text']!= 'Not rated']

# %%
plt.figure(figsize=(6, 4))  
df['Rating text'].value_counts().plot(kind = 'pie',startangle=90,wedgeprops={'edgecolor': 'black'})
plt.title("Average Rarings")
plt.ylabel('')
plt.show()

# %%
x = df[['Average Cost for two', 'Has Table booking','Has Online delivery','Price range']]

# %%
# Above 2 below 2.5 Poor
# Above 2.5 below 3.5 Avarege 
# Above 3.5 below 4.0 Good
# Above 4 below 4.5 Very Good
# Above 4.5 Excellent

# %%
y = df[['Aggregate rating']]

# %%
x
# Out:
#       Average Cost for two Has Table booking Has Online delivery  Price range
# 0                     1100               Yes                  No            3
# 1                     1200               Yes                  No            3
# 2                     4000               Yes                  No            4
# 3                     1500                No                  No            4
# 4                     1500               Yes                  No            4
# ...                    ...               ...                 ...          ...
# 9546                    80                No                  No            3
# 9547                   105                No                  No            3
# 9548                   170                No                  No            4
# 9549                   120                No                  No            4
# 9550                    55                No                  No            2
#
# [7403 rows x 4 columns]

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()

# %%
x['Has Table booking'] = lb.fit_transform(x['Has Table booking'])
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_3384\617506876.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['Has Table booking'] = lb.fit_transform(x['Has Table booking'])

# %%
lb.classes_
# Out:
# array(['No', 'Yes'], dtype=object)

# %% [markdown]
# Has Table booking : 1 is yes , 0 is no

# %%
x['Has Online delivery'] = lb.fit_transform(x['Has Online delivery'])
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_3384\3925057605.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['Has Online delivery'] = lb.fit_transform(x['Has Online delivery'])

# %%
lb.classes_
# Out:
# array(['No', 'Yes'], dtype=object)

# %% [markdown]
# Has Online delivery : 1 is yes , 0 is no

# %% [markdown]
# ## Sceling

# %%
from sklearn.preprocessing import StandardScaler
sd = StandardScaler()

# %%
x = sd.fit_transform(x)

# %%
x
# Out:
# array([[-0.0190367 ,  2.37978283, -0.68302371,  1.10671644],
#        [-0.0135729 ,  2.37978283, -0.68302371,  1.10671644],
#        [ 0.13941344,  2.37978283, -0.68302371,  2.18135204],
#        ...,
#        [-0.06985002, -0.42020641, -0.68302371,  2.18135204],
#        [-0.07258191, -0.42020641, -0.68302371,  2.18135204],
#        [-0.07613338, -0.42020641, -0.68302371,  0.03208084]])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
def modelresult(prediction):
    print("Mean absoult error on model is {}".format(mean_absolute_error(y_test,prediction)))
    print("Root mean squred error on model is {}".format(np.sqrt(mean_squared_error(y_test,prediction))))

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict(x_test)
# Out:
# array([[3.14761484],
#        [3.22941623],
#        [3.6730271 ],
#        ...,
#        [3.49321871],
#        [3.58811655],
#        [3.50594971]])

# %%
predictionsformlr = lr.predict(x_test)

# %%
modelresult(predictionsformlr)
# Out:
# Mean absoult error on model is 0.40046572987664586
# Root mean squred error on model is 0.5030577037149181

# %%
predictionsformlr
# Out:
# array([[3.14761484],
#        [3.22941623],
#        [3.6730271 ],
#        ...,
#        [3.49321871],
#        [3.58811655],
#        [3.50594971]])

# %% [markdown]
# ## Support vector regression

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV

# Define the SVR model
svrmodel = SVR()

# Set up the parameter grid
param_gridsvr = {
    "C": [0.1, 0.5],
    "kernel": ["linear", "poly"],
    "degree": [2]
}

# Set up and run the grid search
gridsvr = GridSearchCV(svrmodel, param_gridsvr)
gridsvr.fit(x_train, y_train)
# Out:
# c:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
predsgridsvr = gridsvr.predict(x_test)

# %%
modelresult(predsgridsvr)
# Out:
# Mean absoult error on model is 0.39357618222058927
# Root mean squred error on model is 0.5008021113656903

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
param_grid  = {
    "max_depth" : [10,30],
    "min_samples_leaf" : [1,2],
    "min_samples_split" : [2,5]
}

# %%
treemodel = DecisionTreeRegressor()

# %%
grid_tree = GridSearchCV(estimator = treemodel,param_grid=param_grid)

# %%
grid_tree.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeRegressor(),
#              param_grid={'max_depth': [10, 30], 'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5]})

# %% [markdown]
# ## Prediction

# %%
treepredction = grid_tree.predict(x_test)

# %%
modelresult(treepredction)
# Out:
# Mean absoult error on model is 0.3533090749822089
# Root mean squred error on model is 0.4514421079982764

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfrmodel = RandomForestRegressor()

# %%
param_gridrfr = {"max_depth": [5,15],"n_estimators" : [2,5,10]}

# %%
gridrfr = GridSearchCV(rfrmodel,param_gridrfr)

# %%
gridrfr.fit(x_train,y_train)
# Out:
# c:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# ...

# %%
randomforestpredictions = gridrfr.predict(x_test)

# %%
modelresult(randomforestpredictions)
# Out:
# Mean absoult error on model is 0.3526379591618683
# Root mean squred error on model is 0.4484230100213452

# %%
gridrfr.best_params_
# Out:
# {'max_depth': 5, 'n_estimators': 5}

# %%
grid_tree.best_params_
# Out:
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5}

# %%
from sklearn.neighbors import KNeighborsRegressor

knn = KNeighborsRegressor()
knn_param_grid = {"n_neighbors": [9,11,14,15,16]}
knn_grid_search = GridSearchCV(knn, knn_param_grid)

# %%
knn_grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=KNeighborsRegressor(),
#              param_grid={'n_neighbors': [9, 11, 14, 15, 16]})

# %%
knnpreds = knn_grid_search.predict(x_test)

# %%
modelresult(knnpreds)
# Out:
# Mean absoult error on model is 0.37094024307900064
# Root mean squred error on model is 0.4690335345503007

# %%
knn_grid_search.best_params_
# Out:
# {'n_neighbors': 16}

# %%
from sklearn.ensemble import AdaBoostRegressor
ada = AdaBoostRegressor()
ada_param_grid = {"n_estimators":[50,100,200],
                 "learning_rate":[0.1,0.5,1]}
ada_grid_search = GridSearchCV(ada,ada_param_grid)

# %%
ada_grid_search.fit(x_train,y_train)
# Out:
# c:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
adapreds = ada_grid_search.predict(x_test)

# %%
modelresult(adapreds)
# Out:
# Mean absoult error on model is 0.3673961110788326
# Root mean squred error on model is 0.4615378087336353

# %%
gridrfr
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [5, 15], 'n_estimators': [2, 5, 10]})

# %%
import joblib
joblib.dump(gridrfr,"mlmodel.pk")
# Out:
# ['mlmodel.pk']

# %%
sd
# Out:
# StandardScaler()

# %%
joblib.dump(sd, "Scaler.pkl")
# Out:
# ['Scaler.pkl']
